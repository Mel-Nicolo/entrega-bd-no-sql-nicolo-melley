# %% [markdown]
# # Cuaderno RETO 1: Exploración de los datos
#
# En este cuaderno se realiza la **exploración inicial del dataset terrazas** proporcionado
# para la práctica de Bases de Datos NoSQL.
#
# El objetivo de este reto es **comprender la estructura, el contenido y la calidad de los datos**
# sin realizar todavía tareas de limpieza ni inserción en la base de datos.
#
# Esta exploración permitirá identificar:
# - Número de registros y atributos
# - Tipos de datos
# - Valores nulos
# - Posibles claves y relaciones
# - Problemas de calidad de los datos

# %% [markdown]
# ### Contexto del conjunto de datos (Terrazas)
#
# El conjunto de datos describe las terrazas autorizadas asociadas a locales comerciales
# del municipio de Madrid, incluyendo información administrativa, geográfica y de actividad.
#
# Cada registro identifica una terraza mediante un código único (`id_terraza`) y la vincula
# a un local (`id_local`), el cual se asocia a una dirección oficial del edificio, distrito y barrio.
# Los locales se clasifican según su tipo de acceso (puerta de calle, agrupado, interior, etc.)
# y su situación administrativa (abierto, cerrado, en obras, baja, uso vivienda).
#
# El dataset incluye información de ubicación (dirección postal y coordenadas UTM),
# características físicas de la terraza (superficie, número de mesas y sillas),
# periodo de funcionamiento (anual o estacional) y horarios autorizados,
# diferenciando entre días laborables y fines de semana.
#
# Los datos proceden del Censo de Locales y Actividades y reflejan la última situación
# administrativa disponible para cada local con terraza abierta.

# %%
# Imports necesarios
import pandas as pd 

# Configuración para mostrar todas las filas y columnas sin truncar
pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# ### Carga del dataset
#
# En primer lugar se carga el fichero CSV.
# Este dataset contiene datos relativos a las terrazas de hostelería y restauración
# que constan asociadas a locales del censo de locales y actividades del Ayuntamiento de
# Madrid.
#
# El fichero utiliza el carácter `;` como separador de campos.

# %%
df_terrazas = pd.read_csv("../../data/raw/terrazas202312.csv", sep=';')

# Mostramos el tamaño del DataFrame (número de filas y columnas)
print(df_terrazas.shape)
# Out:
# (6788, 61)

# %% [markdown]
# El resultado anterior indica que en total tenemos 6788 filas y 61 columnas presentes en el dataset.
#
# A continuación vamos a visualizar las primeras filas del dataset para obtener una primera idea del contenido y formato de los datos.

# %%
df_terrazas.head()
# Out:
#    id_terraza   id_local  id_distrito_local   desc_distrito_local  \
# 0          33  270403150                  4  SALAMANCA
# 1        1168   80000291                  8  FUENCARRAL-EL PARDO
# 2          42   40002970                  4  SALAMANCA
# 3        1176   40002488                  4  SALAMANCA
# 4          56  170000773                 17  VILLAVERDE
#
#    id_barrio_local     desc_barrio_local  id_ndp_edificio  \
# 0              404  GUINDALERA                   11018870
# 1              806  VALVERDE                     20057165
# 2              403  FUENTE DEL BERRO             11016907
# 3              406  CASTELLANA                   11019901
# 4             1704  LOS ROSALES                  11126803
#
#    id_clase_ndp_edificio  id_vial_edificio       clase_vial_edificio  \
# 0                      1             42500  AVENIDA
# 1                      1               127  CALLE
# 2                      1          88952587  CALLE
# 3                      1            411300  CALLE
# 4                      1            786850  CALLE
#
#                                    desc_vial_edificio nom_edificio  \
# 0  AMERICA                                                     NUM
# 1  ISABEL COLBRAND                                             NUM
# 2  ALCALA                                                      NUM
# 3  JUAN BRAVO                                                  NUM
# 4  VILLAJOYOSA                                                 NUM
#
#    num_edificio  Cod_Postal  coordenada_x_local  coordenada_y_local  \
# 0             2       28028           442586.60           4476524.5
# 1            10       28050                0.00                 0.0
# 2           200       28028           443685.60           4475723.5
# 3            25       28006           442284.60           4476020.5
# 4            73       28041           441341.53           4467433.5
#
#    id_tipo_acceso_local desc_tipo_acceso_local  id_situacion_local  \
# 0                     1           Puerta Calle                   1
# 1                     0               Agrupado                   1
# 2                     1           Puerta Calle                   1
# 3                     1           Puerta Calle                   1
# 4                     1           Puerta Calle                   1
#
#   desc_situacion_local  secuencial_local_PC Escalera id_planta_agrupado  \
# 0              Abierto                   30      NaN                 PB
# 1              Abierto                    0      NaN                 PB
# 2              Abierto                   20      NaN                 PB
# 3              Abierto                   20      NaN                 PB
# 4              Abierto                   10      NaN                 PB
#
#   id_local_agrupado  coordenada_x_agrupacion  coordenada_y_agrupacion  \
# 0                01                      NaN                      NaN
# 1              EX71                442993.62                4484849.5
# 2               NaN                      NaN                      NaN
# 3               NaN                      NaN                      NaN
# 4                01                      NaN                      NaN
#
#                 rotulo  id_periodo_terraza desc_periodo_terraza  \
# 0                 VIPS                   1                Anual
# 1   RESTAURANTE DOMINÓ                   1                Anual
# 2                 VIPS                   1                Anual
# 3              SALITRE                   1                Anual
# 4  DONER KEBAB ARMENIA                   2           Estacional
#
#    id_situacion_terraza desc_situacion_terraza  Superficie_ES  Superficie_RA  \
# 0                     1                Abierta          21.06          16.20
# 1                     1                Abierta          89.04          89.04
# 2                     1                Abierta          14.89          14.89
# 3                     1                Abierta          27.00          27.00
# 4                     1                Abierta          12.96            NaN
#
#   Fecha_confir_ult_decreto_resol  id_ndp_terraza  id_clase_ndp_terraza  \
# 0                     04/04/2014        11018870                     1
# 1                     15/12/2014        20057165                     1
# 2                     07/04/2014        11016907                     1
# 3                     17/12/2014        11019901                     1
# 4                     14/04/2014        11126803                     1
#
#     id_vial                desc_clase  \
# 0     42500  AVENIDA
# 1       127  CALLE
# 2  88952587  CALLE
# 3    411300  CALLE
# 4    786850  CALLE
#
#                                           desc_nombre nom_terraza  \
# 0  AMERICA                                                    NUM
# 1  ISABEL COLBRAND                                            NUM
# 2  ALCALA                                                     NUM
# 3  JUAN BRAVO                                                 NUM
# 4  VILLAJOYOSA                                                NUM
#
#    num_terraza cal_terraza         desc_ubicacion_terraza hora_ini_LJ_es  \
# 0            2                                      Acera       10:00:00
# 1           10              Superficie en parcela privada       09:00:00
# 2          200           A                          Acera       08:00:00
# 3           25                                    Bulevar       10:00:00
# 4           73                                      Acera       08:00:00
#
#   hora_fin_LJ_es hora_ini_LJ_ra hora_fin_LJ_ra hora_ini_VS_es hora_fin_VS_es  \
# 0       01:00:00       10:00:00       00:00:00       10:00:00       02:30:00
# 1       01:00:00       09:00:00       00:00:00       09:00:00       02:30:00
# 2       01:00:00       08:00:00       00:00:00       08:00:00       01:30:00
# 3       00:00:00       10:00:00       00:00:00       10:00:00       00:00:00
# 4       01:30:00            NaN            NaN       08:00:00       01:30:00
#
#   hora_ini_VS_ra hora_fin_VS_ra  mesas_aux_es  mesas_aux_ra  mesas_es  \
# 0       10:00:00       00:00:00             0           0.0         9
# 1       09:00:00       00:00:00             0           0.0        22
# 2       08:00:00       00:00:00             0           0.0         4
# 3       10:00:00       00:00:00             0           0.0        18
# 4            NaN            NaN             0           0.0         4
#
#    mesas_ra  sillas_es  sillas_ra cal_edificio                 fx_carga  \
# 0       9.0         27       27.0               2023-12-08 07:00:49.223
# 1      22.0         70       70.0               2023-12-08 07:00:49.227
# 2       0.0         16        0.0            A  2023-12-08 07:00:49.223
# 3      18.0         36       36.0               2023-12-08 07:00:49.227
# 4       0.0         16        0.0               2023-12-08 07:00:49.223
#
#   fx_datos_ini fx_datos_fin
# 0   2023-12-01   2023-12-01
# 1   2023-12-01   2023-12-01
# 2   2023-12-01   2023-12-01
# 3   2023-12-01   2023-12-01
# 4   2023-12-01   2023-12-01

# %% [markdown]
# A continuación se muestra una muestra aleatoria de registros.
# Esto permite observar valores representativos que no necesariamente
# aparecen en las primeras filas del fichero.

# %%
df_terrazas.sample(5, random_state=42)
# Out:
#       id_terraza   id_local  id_distrito_local   desc_distrito_local  \
# 4077       18431   60001187                  6  TETUAN
# 5309       18411  270349370                  7  CHAMBERI
# 101          813  285043131                 15  CIUDAD LINEAL
# 2077        4718  270379088                 10  LATINA
# 2225        4836  190000300                 19  VICALVARO
#
#       id_barrio_local     desc_barrio_local  id_ndp_edificio  \
# 4077              603  CASTILLEJOS                  11030975
# 5309              705  RIOS ROSAS                   11041744
# 101              1501  VENTAS                       11103522
# 2077             1005  CAMPAMENTO                   11066309
# 2225             1901  CASCO H.VICALVARO            11133075
#
#       id_clase_ndp_edificio  id_vial_edificio       clase_vial_edificio  \
# 4077                      1            137400  CALLE
# 5309                      1            276200  CALLE
# 101                       1            675700  CALLE
# 2077                      1            785800  CALLE
# 2225                      1             78200  PASEO
#
#                                       desc_vial_edificio nom_edificio  \
# 4077  POETA JOAN MARAGALL                                         NUM
# 5309  ESPRONCEDA                                                  NUM
# 101   SAN LAMBERTO                                                NUM
# 2077  VILLACARRIEDO                                               NUM
# 2225  ARTILLEROS                                                  NUM
#
#       num_edificio  Cod_Postal  coordenada_x_local  coordenada_y_local  \
# 4077            51       28020           441287.62           4479404.5
# 5309            17       28003           440855.60           4476905.5
# 101             19       28017           444704.56           4474679.5
# 2077             6       28024           434533.62           4472175.5
# 2225            15       28032           448332.53           4473135.5
#
#       id_tipo_acceso_local desc_tipo_acceso_local  id_situacion_local  \
# 4077                     1           Puerta Calle                   1
# 5309                     1           Puerta Calle                   1
# 101                      1           Puerta Calle                   1
# 2077                     1           Puerta Calle                   1
# 2225                     1           Puerta Calle                   1
#
#      desc_situacion_local  secuencial_local_PC Escalera id_planta_agrupado  \
# 4077              Abierto                   40      NaN                 PB
# 5309              Abierto                   20      NaN                 PB
# 101               Abierto                   50      NaN                 PB
# 2077              Abierto                   10      NaN                 PB
# 2225              Abierto                   10      NaN                 SO
#
#      id_local_agrupado  coordenada_x_agrupacion  coordenada_y_agrupacion  \
# 4077               NaN                      NaN                      NaN
# 5309                04                      NaN                      NaN
# 101                 02                      NaN                      NaN
# 2077               NaN                      NaN                      NaN
# 2225                01                      NaN                      NaN
#
#                     rotulo  id_periodo_terraza desc_periodo_terraza  \
# 4077   51 NIGHTS OF DRINKS                   1                Anual
# 5309  CAFETERIA SYLKAR BAR                   1                Anual
# 101       LA TAPITA DE EVA                   1                Anual
# 2077              PIKATAPA                   2           Estacional
# 2225   BAR RINCON DE CARLA                   1                Anual
#
#       id_situacion_terraza desc_situacion_terraza  Superficie_ES  \
# 4077                     1                Abierta          36.00
# 5309                     1                Abierta          41.20
# 101                      1                Abierta          25.92
# 2077                     1                Abierta          45.12
# 2225                     1                Abierta          34.56
#
#       Superficie_RA Fecha_confir_ult_decreto_resol  id_ndp_terraza  \
# 4077          36.00                     02/02/2021        11030975
# 5309          41.20                     29/01/2021        31044178
# 101           25.92                     18/08/2014        11103522
# 2077            NaN                     09/01/2017        11066309
# 2225          34.56                     10/01/2017        20048924
#
#       id_clase_ndp_terraza  id_vial                desc_clase  \
# 4077                     1   137400  CALLE
# 5309                     1   276200  CALLE
# 101                      1   675700  CALLE
# 2077                     1   785800  CALLE
# 2225                     1   786760  CALLE
#
#                                              desc_nombre nom_terraza  \
# 4077  POETA JOAN MARAGALL                                        NUM
# 5309  ESPRONCEDA                                                 NUM
# 101   SAN LAMBERTO                                               NUM
# 2077  VILLACARRIEDO                                              NUM
# 2225  VILLAJIMENA                                                NUM
#
#       num_terraza cal_terraza   desc_ubicacion_terraza hora_ini_LJ_es  \
# 4077           51                       Calle peatonal       10:00:00
# 5309           17           B  Zona de estacionamiento       10:00:00
# 101            19                                Acera       08:00:00
# 2077            6                                Otros       10:00:00
# 2225            2           C                    Acera       08:00:00
#
#      hora_fin_LJ_es hora_ini_LJ_ra hora_fin_LJ_ra hora_ini_VS_es  \
# 4077       01:00:00       10:00:00       00:00:00       10:00:00
# 5309       01:30:00       10:00:00       01:00:00       10:00:00
# 101        01:30:00       08:00:00       01:00:00       08:00:00
# 2077       00:00:00            NaN            NaN       10:00:00
# 2225       01:30:00       08:00:00       01:00:00       08:00:00
#
#      hora_fin_VS_es hora_ini_VS_ra hora_fin_VS_ra  mesas_aux_es  mesas_aux_ra  \
# 4077       02:00:00       10:00:00       00:00:00             0           0.0
# 5309       01:30:00       10:00:00       01:00:00             0           0.0
# 101        01:30:00       08:00:00       01:00:00             0           0.0
# 2077       00:00:00            NaN            NaN             0           NaN
# 2225       01:30:00       08:00:00       01:00:00             0           0.0
#
#       mesas_es  mesas_ra  sillas_es  sillas_ra cal_edificio  \
# 4077        10      10.0         38       38.0
# 5309         6       6.0         24       24.0
# 101          8       8.0         32       32.0
# 2077        10       NaN         40        NaN
# 2225        14      14.0         43       43.0
#
#                      fx_carga fx_datos_ini fx_datos_fin
# 4077  2023-12-08 07:00:49.233   2023-12-01   2023-12-01
# 5309  2023-12-08 07:00:49.237   2023-12-01   2023-12-01
# 101   2023-12-08 07:00:49.227   2023-12-01   2023-12-01
# 2077   2023-12-08 07:00:49.23   2023-12-01   2023-12-01
# 2225   2023-12-08 07:00:49.23   2023-12-01   2023-12-01

# %% [markdown]
# ### Estructura y tipos de datos
#
# Se analiza la estructura del DataFrame para identificar:
# - Nombre de los atributos
# - Tipo de dato asignado por pandas
# - Número de valores no nulos por columna

# %%
df_terrazas.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6788 entries, 0 to 6787
# Data columns (total 61 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id_terraza                      6788 non-null   int64
#  1   id_local                        6788 non-null   int64
#  2   id_distrito_local               6788 non-null   int64
#  3   desc_distrito_local             6788 non-null   str
#  4   id_barrio_local                 6788 non-null   int64
#  5   desc_barrio_local               6788 non-null   str
#  6   id_ndp_edificio                 6788 non-null   int64
#  7   id_clase_ndp_edificio           6788 non-null   int64
#  8   id_vial_edificio                6788 non-null   int64
#  9   clase_vial_edificio             6788 non-null   str
#  10  desc_vial_edificio              6788 non-null   str
#  11  nom_edificio                    6788 non-null   str
#  12  num_edificio                    6788 non-null   int64
#  13  Cod_Postal                      6788 non-null   int64
#  14  coordenada_x_local              6788 non-null   float64
#  15  coordenada_y_local              6788 non-null   float64
#  16  id_tipo_acceso_local            6788 non-null   int64
#  17  desc_tipo_acceso_local          6788 non-null   str
#  18  id_situacion_local              6788 non-null   int64
#  19  desc_situacion_local            6788 non-null   str
#  20  secuencial_local_PC             6788 non-null   int64
#  21  Escalera                        123 non-null    str
#  22  id_planta_agrupado              6784 non-null   str
#  23  id_local_agrupado               5524 non-null   str
#  24  coordenada_x_agrupacion         105 non-null    float64
#  25  coordenada_y_agrupacion         105 non-null    float64
#  26  rotulo                          6788 non-null   str
#  27  id_periodo_terraza              6788 non-null   int64
#  28  desc_periodo_terraza            6788 non-null   str
#  29  id_situacion_terraza            6788 non-null   int64
#  30  desc_situacion_terraza          6788 non-null   str
#  31  Superficie_ES                   6788 non-null   float64
#  32  Superficie_RA                   5610 non-null   float64
#  33  Fecha_confir_ult_decreto_resol  6788 non-null   str
#  34  id_ndp_terraza                  6788 non-null   int64
#  35  id_clase_ndp_terraza            6788 non-null   int64
#  36  id_vial                         6788 non-null   int64
#  37  desc_clase                      6788 non-null   str
#  38  desc_nombre                     6788 non-null   str
#  39  nom_terraza                     6788 non-null   str
#  40  num_terraza                     6788 non-null   int64
#  41  cal_terraza                     6788 non-null   str
#  42  desc_ubicacion_terraza          6788 non-null   str
#  43  hora_ini_LJ_es                  6788 non-null   str
#  44  hora_fin_LJ_es                  6788 non-null   str
#  45  hora_ini_LJ_ra                  5610 non-null   str
#  46  hora_fin_LJ_ra                  5610 non-null   str
#  47  hora_ini_VS_es                  6788 non-null   str
#  48  hora_fin_VS_es                  6788 non-null   str
#  49  hora_ini_VS_ra                  5610 non-null   str
#  50  hora_fin_VS_ra                  5610 non-null   str
#  51  mesas_aux_es                    6788 non-null   int64
#  52  mesas_aux_ra                    6549 non-null   float64
#  53  mesas_es                        6788 non-null   int64
#  54  mesas_ra                        6549 non-null   float64
#  55  sillas_es                       6788 non-null   int64
#  56  sillas_ra                       6549 non-null   float64
#  57  cal_edificio                    6788 non-null   str
#  58  fx_carga                        6788 non-null   str
#  59  fx_datos_ini                    6788 non-null   str
#  60  fx_datos_fin                    6788 non-null   str
# dtypes: float64(9), int64(21), str(31)
# memory usage: 3.2 MB

# %% [markdown]
# A partir de esta información se puede observar que:
# - Existen 9 columnas de tipo float.
# - Existen 21 columnas de tipo int64.
# - Existen 31 columnas de tipo str.
# - Los campos que representan fechas están representados como str.

# %% [markdown]
# ### Análisis de valores nulos
#
# Se comprueba la existencia de valores nulos en el dataset.
# En esta fase **no se eliminan ni corrigen**, únicamente se identifican.

# %%
df_terrazas.isnull().sum()[df_terrazas.isnull().sum() > 0]
# Out:
# Escalera                   6665
# id_planta_agrupado            4
# id_local_agrupado          1264
# coordenada_x_agrupacion    6683
# coordenada_y_agrupacion    6683
# Superficie_RA              1178
# hora_ini_LJ_ra             1178
# hora_fin_LJ_ra             1178
# hora_ini_VS_ra             1178
# hora_fin_VS_ra             1178
# mesas_aux_ra                239
# mesas_ra                    239
# sillas_ra                   239
# dtype: int64

# %% [markdown]
# El resultado muestra qué columnas contienen valores nulos y cuántos registros se ven afectados en cada caso.

# %% [markdown]
# ### Análisis de columnas de texto
#
# Se identifican las columnas de tipo texto para analizar posibles problemas de calidad, como espacios en blanco innecesarios o formatos inconsistentes.

# %%
text_cols = df_terrazas.select_dtypes(include="object").columns
print(text_cols)
# Out:
# Index(['desc_distrito_local', 'desc_barrio_local', 'clase_vial_edificio',
#        'desc_vial_edificio', 'nom_edificio', 'desc_tipo_acceso_local',
#        'desc_situacion_local', 'Escalera', 'id_planta_agrupado',
#        'id_local_agrupado', 'rotulo', 'desc_periodo_terraza',
#        'desc_situacion_terraza', 'Fecha_confir_ult_decreto_resol',
#        'desc_clase', 'desc_nombre', 'nom_terraza', 'cal_terraza',
#        'desc_ubicacion_terraza', 'hora_ini_LJ_es', 'hora_fin_LJ_es',
#        'hora_ini_LJ_ra', 'hora_fin_LJ_ra', 'hora_ini_VS_es', 'hora_fin_VS_es',
#        'hora_ini_VS_ra', 'hora_fin_VS_ra', 'cal_edificio', 'fx_carga',
#        'fx_datos_ini', 'fx_datos_fin'],
#       dtype='str')
# C:\Users\spara\AppData\Local\Temp\ipykernel_504\1160555289.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   text_cols = df_terrazas.select_dtypes(include="object").columns

# %% [markdown]
# A continuación se inspeccionan los valores únicos de una columna de texto representativa para observar posibles inconsistencias.

# %%
df_terrazas["desc_barrio_local"].unique()
# Out:
# <StringArray>
# ['GUINDALERA          ', 'VALVERDE            ', 'FUENTE DEL BERRO    ',
#  'CASTELLANA          ', 'LOS ROSALES         ', 'UNIVERSIDAD         ',
#  'EMBAJADORES         ', 'JUSTICIA            ', 'CASCO H.VALLECAS    ',
#  'PALACIO             ',
#  ...
#  'VALDEFUENTES        ', 'CUATRO VIENTOS      ', 'CANILLAS            ',
#  'PIOVERA             ', 'PINAR DEL REY       ', 'APOSTOL SANTIAGO    ',
#  'PALOMAS             ',         'EL CAÑAVERAL', 'VALDEMARIN          ',
#  'FUENTELARREINA      ']
# Length: 129, dtype: str

# %% [markdown]
# En los valores mostrados se puede observar la presencia de espacios en blanco
# al final de las cadenas de texto, lo que indica que será necesario realizar
# un preprocesado mínimo antes de la inserción en la base de datos.

# %% [markdown]
# ### Identificación de columnas de fecha
#
# Se identifican las columnas que contienen información temporal.
# Estas columnas suelen comenzar por el prefijo `fx_` o `fecha`.

# %%
date_cols = [c for c in df_terrazas.columns if "fx_" in c.lower() or "fecha" in c.lower()]
print(date_cols)
# Out:
# ['Fecha_confir_ult_decreto_resol', 'fx_carga', 'fx_datos_ini', 'fx_datos_fin']

# %% [markdown]
# Las columnas identificadas contienen fechas almacenadas como texto,
# por lo que será necesario convertirlas a un formato de fecha adecuado
# en fases posteriores para permitir consultas temporales.

# %% [markdown]
# ### Identificación de columnas de hora
#
# Se identifican las columnas que contienen información temporal.
# Estas columnas suelen comenzar por el prefijo `hora`.

# %%
hour_cols = [c for c in df_terrazas.columns if "hora" in c.lower()]
print(hour_cols)
# Out:
# ['hora_ini_LJ_es', 'hora_fin_LJ_es', 'hora_ini_LJ_ra', 'hora_fin_LJ_ra', 'hora_ini_VS_es', 'hora_fin_VS_es', 'hora_ini_VS_ra', 'hora_fin_VS_ra']

# %% [markdown]
# Las columnas identificadas contienen horas almacenadas como texto,
# por lo que será necesario convertirlas a un formato de hora adecuado
# en fases posteriores para permitir consultas temporales.

# %% [markdown]
# ### Listado completo de columnas
#
# A continuación, se muestra el listado completo de atributos del dataset para identificar posibles claves y relaciones con otros ficheros.

# %%
# Crea una tabla con dos columnas: "Columna" y "Tipo"
tipos_df = df_terrazas.dtypes.reset_index()
tipos_df.columns = ['Columna', 'Tipo de Dato']

tipos_df.style.set_properties(**{'text-align': 'left'}).hide(axis='index')
# Out:
# <style type="text/css">
# #T_eefad_row0_col0, #T_eefad_row0_col1, #T_eefad_row1_col0, #T_eefad_row1_col1, #T_eefad_row2_col0, #T_eefad_row2_col1, #T_eefad_row3_col0, #T_eefad_row3_col1, #T_eefad_row4_col0, #T_eefad_row4_col1, #T_eefad_row5_col0, #T_eefad_row5_col1, #T_eefad_row6_col0, #T_eefad_row6_col1, #T_eefad_row7_col0, #T_eefad_row7_col1, #T_eefad_row8_col0, #T_eefad_row8_col1, #T_eefad_row9_col0, #T_eefad_row9_col1, #T_eefad_row10_col0, #T_eefad_row10_col1, #T_eefad_row11_col0, #T_eefad_row11_col1, #T_eefad_row12_col0, #T_eefad_row12_col1, #T_eefad_row13_col0, #T_eefad_row13_col1, #T_eefad_row14_col0, #T_eefad_row14_col1, #T_eefad_row15_col0, #T_eefad_row15_col1, #T_eefad_row16_col0, #T_eefad_row16_col1, #T_eefad_row17_col0, #T_eefad_row17_col1, #T_eefad_row18_col0, #T_eefad_row18_col1, #T_eefad_row19_col0, #T_eefad_row19_col1, #T_eefad_row20_col0, #T_eefad_row20_col1, #T_eefad_row21_col0, #T_eefad_row21_col1, #T_eefad_row22_col0, #T_eefad_row22_col1, #T_eefad_row23_col0, #T_eefad_row23_col1, #T_eefad_row24_col0, #T_eefad_row24_col1, #T_eefad_row25_col0, #T_eefad_row25_col1, #T_eefad_row26_col0, #T_eefad_row26_col1, #T_eefad_row27_col0, #T_eefad_row27_col1, #T_eefad_row28_col0, #T_eefad_row28_col1, #T_eefad_row29_col0, #T_eefad_row29_col1, #T_eefad_row30_col0, #T_eefad_row30_col1, #T_eefad_row31_col0, #T_eefad_row31_col1, #T_eefad_row32_col0, #T_eefad_row32_col1, #T_eefad_row33_col0, #T_eefad_row33_col1, #T_eefad_row34_col0, #T_eefad_row34_col1, #T_eefad_row35_col0, #T_eefad_row35_col1, #T_eefad_row36_col0, #T_eefad_row36_col1, #T_eefad_row37_col0, #T_eefad_row37_col1, #T_eefad_row38_col0, #T_eefad_row38_col1, #T_eefad_row39_col0, #T_eefad_row39_col1, #T_eefad_row40_col0, #T_eefad_row40_col1, #T_eefad_row41_col0, #T_eefad_row41_col1, #T_eefad_row42_col0, #T_eefad_row42_col1, #T_eefad_row43_col0, #T_eefad_row43_col1, #T_eefad_row44_col0, #T_eefad_row44_col1, #T_eefad_row45_col0, #T_eefad_row45_col1, #T_eefad_row46_col0, #T_eefad_row46_col1, #T_eefad_row47_col0, #T_eefad_row47_col1, #T_eefad_row48_col0, #T_eefad_row48_col1, #T_eefad_row49_col0, #T_eefad_row49_col1, #T_eefad_row50_col0, #T_eefad_row50_col1, #T_eefad_row51_col0, #T_eefad_row51_col1, #T_eefad_row52_col0, #T_eefad_row52_col1, #T_eefad_row53_col0, #T_eefad_row53_col1, #T_eefad_row54_col0, #T_eefad_row54_col1, #T_eefad_row55_col0, #T_eefad_row55_col1, #T_eefad_row56_col0, #T_eefad_row56_col1, #T_eefad_row57_col0, #T_eefad_row57_col1, #T_eefad_row58_col0, #T_eefad_row58_col1, #T_eefad_row59_col0, #T_eefad_row59_col1, #T_eefad_row60_col0, #T_eefad_row60_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_eefad">
#   <thead>
#     <tr>
#       <th id="T_eefad_level0_col0" class="col_heading level0 col0" >Columna</th>
#       <th id="T_eefad_level0_col1" class="col_heading level0 col1" >Tipo de Dato</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_eefad_row0_col0" class="data row0 col0" >id_terraza</td>
#       <td id="T_eefad_row0_col1" class="data row0 col1" >int64</td>
#     </tr>
#     <tr>
#       <td id="T_eefad_row1_col0" class="data row1 col0" >id_local</td>
#       <td id="T_eefad_row1_col1" class="data row1 col1" >int64</td>
#     </tr>
#     <tr>
#       <td id="T_eefad_row2_col0" class="data row2 col0" >id_distrito_local</td>
#       <td id="T_eefad_row2_col1" class="data row2 col1" >int64</td>
#     </tr>
#     <tr>
#       <td id="T_eefad_row3_col0" class="data row3 col0" >desc_distrito_local</td>
#       <td id="T_eefad_row3_col1" class="data row3 col1" >str</td>
#     </tr>
#     <tr>
#       <td id="T_eefad_row4_col0" class="data row4 col0" >id_barrio_local</td>
#       <td id="T_eefad_row4_col1" class="data row4 col1" >int64</td>
#     </tr>
#     <tr>
#       <td id="T_eefad_row5_col0" class="data row5 col0" >desc_barrio_local</td>
#       <td id="T_eefad_row5_col1" class="data row5 col1" >str</td>
#     </tr>
#     <tr>
#       <td id="T_eefad_row6_col0" class="data row6 col0" >id_ndp_edificio</td>
#       <td id="T_eefad_row6_col1" class="data row6 col1" >int64</td>
#     </tr>
#     <tr>
#       <td id="T_eefad_row7_col0" class="data row7 col0" >id_clase_ndp_edificio</td>
#       <td id="T_eefad_row7_col1" class="data row7 col1" >int64</td>
#     </tr>
#     <tr>
#       <td id="T_eefad_row8_col0" class="data row8 col0" >id_vial_edificio</td>
#       <td id="T_eefad_row8_col1" class="data row8 col1" >int64</td>
#     </tr>
#     <tr>
#       <td id="T_eefad_row9_col0" class="data row9 col0" >clase_vial_edificio</td>
#       <td id="T_eefad_row9_col1" class="data row9 col1" >str</td>
#     </tr>
#     <tr>
#       <td id="T_eefad_row10_col0" class="data row10 col0" >desc_vial_edificio</td>
#       <td id="T_eefad_row10_col1" class="data row10 col1" >str</td>
#     </tr>
#     <tr>
#       <td id="T_eefad_row11_col0" class="data row11 col0" >nom_edificio</td>
#       <td id="T_eefad_row11_col1" class="data row11 col1" >str</td>
#     </tr>
#     <tr>
#       <td id="T_eefad_row12_col0" class="data row12 col0" >num_edificio</td>
#       <td id="T_eefad_row12_col1" class="data row12 col1" >int64</td>
#     </tr>
#     <tr>
#       <td id="T_eefad_row13_col0" class="data row13 col0" >Cod_Postal</td>
#       <td id="T_eefad_row13_col1" class="data row13 col1" >int64</td>
#     </tr>
#     <tr>
#       <td id="T_eefad_row14_col0" class="data row14 col0" >coordenada_x_local</td>
#       <td id="T_eefad_row14_col1" class="data row14 col1" >float64</td>
#     </tr>
#     <tr>
#       <td id="T_eefad_row15_col0" class="data row15 col0" >coordenada_y_local</td>
#       <td id="T_eefad_row15_col1" class="data row15 col1" >float64</td>
#     </tr>
#     <tr>
#       <td id="T_eefad_row16_col0" class="data row16 col0" >id_tipo_acceso_local</td>
#       <td id="T_eefad_row16_col1" class="data row16 col1" >int64</td>
#     </tr>
#     <tr>
#       <td id="T_eefad_row17_col0" class="data row17 col0" >desc_tipo_acceso_local</td>
#       <td id="T_eefad_row17_col1" class="data row17 col1" >str</td>
#     </tr>
#     <tr>
#       <td id="T_eefad_row18_col0" class="data row18 col0" >id_situacion_local</td>
#       <td id="T_eefad_row18_col1" class="data row18 col1" >int64</td>
#     </tr>
#     <tr>
#       <td id="T_eefad_row19_col0" class="data row19 col0" >desc_situacion_local</td>
#       <td id="T_eefad_row19_col1" class="data row19 col1" >str</td>
#     </tr>
#     <tr>
#       <td id="T_eefad_row20_col0" class="data row20 col0" >secuencial_local_PC</td>
#       <td id="T_eefad_row20_col1" class="data row20 col1" >int64</td>
#     </tr>
#     <tr>
#       <td id="T_eefad_row21_col0" class="data row21 col0" >Escalera</td>
#       <td id="T_eefad_row21_col1" class="data row21 col1" >str</td>
#     </tr>
#     <tr>
#       <td id="T_eefad_row22_col0" class="data row22 col0" >id_planta_agrupado</td>
#       <td id="T_eefad_row22_col1" class="data row22 col1" >str</td>
#     </tr>
#     <tr>
#       <td id="T_eefad_row23_col0" class="data row23 col0" >id_local_agrupado</td>
#       <td id="T_eefad_row23_col1" class="data row23 col1" >str</td>
#     </tr>
#     <tr>
#       <td id="T_eefad_row24_col0" class="data row24 col0" >coordenada_x_agrupacion</td>
#       <td id="T_eefad_row24_col1" class="data row24 col1" >float64</td>
#     </tr>
#     <tr>
#       <td id="T_eefad_row25_col0" class="data row25 col0" >coordenada_y_agrupacion</td>
#       <td id="T_eefad_row25_col1" class="data row25 col1" >float64</td>
#     </tr>
#     <tr>
#       <td id="T_eefad_row26_col0" class="data row26 col0" >rotulo</td>
#       <td id="T_eefad_row26_col1" class="data row26 col1" >str</td>
#     </tr>
#     <tr>
#       <td id="T_eefad_row27_col0" class="data row27 col0" >id_periodo_terraza</td>
#       <td id="T_eefad_row27_col1" class="data row27 col1" >int64</td>
#     </tr>
#     <tr>
#       <td id="T_eefad_row28_col0" class="data row28 col0" >desc_periodo_terraza</td>
#       <td id="T_eefad_row28_col1" class="data row28 col1" >str</td>
#     </tr>
#     <tr>
#       <td id="T_eefad_row29_col0" class="data row29 col0" >id_situacion_terraza</td>
#       <td id="T_eefad_row29_col1" class="data row29 col1" >int64</td>
#     </tr>
#     <tr>
#       <td id="T_eefad_row30_col0" class="data row30 col0" >desc_situacion_terraza</td>
#       <

# %% [markdown]
# ### Conclusión del dataset y campos relevantes para el modelo de datos
#
# A partir de la exploración realizada, se identifican aquellos campos que
# resultan especialmente relevantes para la construcción del modelo de datos,
# ya sea por su papel como identificadores, por permitir relaciones con otros
# datasets o por aportar información estructural clave.

# %%
cols_terrazas_clave = [
    # Identificación y relación
    "id_terraza",
    "id_local",

    # Contexto territorial
    "id_distrito_local",
    "id_barrio_local",
    "desc_barrio_local",

    # Clasificación del local
    "id_tipo_acceso_local",
    "desc_tipo_acceso_local",
    "id_situacion_local",
    "desc_situacion_local",

    # Clasificación de la terraza
    "id_situacion_terraza",
    "desc_situacion_terraza",
    "id_periodo_terraza",
    "desc_periodo_terraza",

    # Características físicas
    "Superficie_ES",
    "Superficie_RA",
    "mesas_es",
    "mesas_ra",
    "sillas_es",
    "sillas_ra",

    # Información temporal
    "Fecha_confir_ult_decreto_resol"
]

df_terrazas[cols_terrazas_clave].drop_duplicates().sample(10, random_state=42)
# Out:
#       id_terraza   id_local  id_distrito_local  id_barrio_local  \
# 4077       18431   60001187                  6              603
# 5309       18411  270349370                  7              705
# 101          813  285043131                 15             1501
# 2077        4718  270379088                 10             1005
# 2225        4836  190000300                 19             1901
# 5602         966  270076479                  4              404
# 469         1741  270184096                 18             1801
# 6574        5828  285011876                  7              703
# 179          955  270029320                  3              306
# 3527       17679  270280325                  5              502
#
#          desc_barrio_local  id_tipo_acceso_local desc_tipo_acceso_local  \
# 4077  CASTILLEJOS                              1           Puerta Calle
# 5309  RIOS ROSAS                               1           Puerta Calle
# 101   VENTAS                                   1           Puerta Calle
# 2077  CAMPAMENTO                               1           Puerta Calle
# 2225  CASCO H.VICALVARO                        1           Puerta Calle
# 5602  GUINDALERA                               1           Puerta Calle
# 469   CASCO H.VALLECAS                         1           Puerta Calle
# 6574  TRAFALGAR                                1           Puerta Calle
# 179   NIÑO JESUS                               1           Puerta Calle
# 3527  PROSPERIDAD                              1           Puerta Calle
#
#       id_situacion_local desc_situacion_local  id_situacion_terraza  \
# 4077                   1              Abierto                     1
# 5309                   1              Abierto                     1
# 101                    1              Abierto                     1
# 2077                   1              Abierto                     1
# 2225                   1              Abierto                     1
# 5602                   1              Abierto                     1
# 469                    1              Abierto                     1
# 6574                   1              Abierto                     1
# 179                    1              Abierto                     1
# 3527                   1              Abierto                     1
#
#      desc_situacion_terraza  id_periodo_terraza desc_periodo_terraza  \
# 4077                Abierta                   1                Anual
# 5309                Abierta                   1                Anual
# 101                 Abierta                   1                Anual
# 2077                Abierta                   2           Estacional
# 2225                Abierta                   1                Anual
# 5602                Abierta                   1                Anual
# 469                 Abierta                   1                Anual
# 6574                Abierta                   1                Anual
# 179                 Abierta                   1                Anual
# 3527                Abierta                   1                Anual
#
#       Superficie_ES  Superficie_RA  mesas_es  mesas_ra  sillas_es  sillas_ra  \
# 4077          36.00          36.00        10      10.0         38       38.0
# 5309          41.20          41.20         6       6.0         24       24.0
# 101           25.92          25.92         8       8.0         32       32.0
# 2077          45.12            NaN        10       NaN         40        NaN
# 2225          34.56          34.56        14      14.0         43       43.0
# 5602          26.25          26.25         6       6.0         12       12.0
# 469           59.50          42.00        18      10.0         72       40.0
# 6574          17.01          17.01         5       5.0         20       20.0
# 179           15.78          15.78         6       6.0         22       22.0
# 3527          44.88          44.88         5       5.0         16       16.0
#
#      Fecha_confir_ult_decreto_resol
# 4077                     02/02/2021
# 5309                     29/01/2021
# 101                      18/08/2014
# 2077                     09/01/2017
# 2225                     10/01/2017
# 5602                     03/10/2014
# 469                      20/03/2015
# 6574                     07/04/2017
# 179                      24/09/2014
# 3527                     08/07/2020

# %% [markdown]
# Los campos seleccionados permiten identificar de forma única cada terraza
# y establecer su relación directa con el local al que pertenece, a través
# de los identificadores `id_terraza` e `id_local`.
#
# Se incluyen los campos territoriales (`id_distrito_local`, `id_barrio_local`,
# `desc_barrio_local`) para analizar la distribución geográfica de las terrazas
# y su posible agregación por zonas.
#
# Asimismo, se consideran los atributos de clasificación del local y de la
# terraza (`id_tipo_acceso_local`, `id_situacion_local`, `id_situacion_terraza`,
# `id_periodo_terraza` y sus descripciones asociadas), ya que permiten comprender
# el estado administrativo y operativo de cada terraza dentro del contexto del
# local.
#
# Finalmente, se incorporan las variables cuantitativas relacionadas con la
# superficie y el mobiliario autorizado (mesas y sillas), dado que representan
# información estructural clave para posteriores análisis y consultas.
#
# La inclusión tanto de identificadores como de descripciones textuales se realiza
# con fines exploratorios, permitiendo interpretar correctamente los códigos y
# facilitando la toma de decisiones en la fase posterior de diseño del modelo
# de datos.
